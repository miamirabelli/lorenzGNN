# %%
# %load_ext autoreload 
# %autoreload 2

from utils.jraph_data import get_lorenz_graph_tuples, print_graph_fts
from utils.lorenz import load_lorenz96_2coupled

import numpy as np
import jax.numpy as jnp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils.jraph_training import train_and_evaluate_with_data, create_dataset, evaluate_model, rollout, train_and_evaluate
# from utils.jraph_models import MLPGraphNetwork
from utils.jraph_data import print_graph_fts
from utils.jraph_vis import plot_predictions
from utils.hyperparam_tuning import remove_bad_trials, get_best_trial_config, get_best_trial_workdir
import ml_collections
import optuna 
from flax import linen as nn
from functools import partial
from datetime import datetime
import os 
import tempfile
import matplotlib.pyplot as plt 
import numpy as np 

import jax
from utils.jraph_training import create_dataset, create_model, create_optimizer
from clu import checkpoint
from clu import parameter_overview
from flax.training import train_state
from utils.lorenz import run_download_lorenz96_2coupled, load_lorenz96_2coupled
from utils.jraph_data import get_lorenz_graph_tuples, print_graph_fts
from utils.lorenz import load_lorenz96_2coupled

# %%
# set up logging
import logging
logger = logging.getLogger()
logger.setLevel(logging.WARNING)

# %%
from utils.jraph_training import train_and_evaluate_with_data, create_dataset
# from utils.jraph_models import MLPGraphNetwork
from utils.jraph_data import print_graph_fts
from utils.jraph_vis import plot_predictions
from utils.hyperparam_tuning import remove_bad_trials, get_best_trial_config, get_best_trial_workdir
import ml_collections
import optuna 
from flax import linen as nn
from functools import partial
from datetime import datetime
import os 
import tempfile

# %%
def get_data_config():
    config = ml_collections.ConfigDict()

    config.n_samples=10_000
    config.input_steps=1
    config.output_delay=8 # predict 24 hrs into the future 
    config.output_steps=4
    config.timestep_duration=3 # equivalent to 3 hours
    # note a 3 hour timestep resolution would be 5*24/3=40
    # if the time_resolution is 120, then a sampling frequency of 3 would achieve a 3 hour timestep 
    config.sample_buffer = -1 * (config.input_steps + config.output_delay + config.output_steps - 1) # negative buffer so that our sample input are continuous (i.e. the first sample would overlap a bit with consecutive samples) 
        # number of timesteps strictly between the end 
        # of one full sample and the start of the next sample
    config.time_resolution=120 # the number of 
                # raw data points generated per time unit, equivalent to the 
                # number of data points generated per 5 days in the simulation
    config.init_buffer_samples=100
    config.train_pct=0.7
    config.val_pct=0.2
    config.test_pct=0.1
    config.K=36
    config.F=8
    config.c=1
    config.b=1
    config.h=1
    config.seed=42
    config.normalize=True
    config.fully_connected_edges=False

    return config

# create config 
config = get_data_config()
config.max_checkpts_to_keep = None # None means keep all

# Optimizer.
config.optimizer = "adam"
config.learning_rate = 0.0004

# Data params that are used in training 
config.output_steps = 4

# Training hyperparameters.
config.batch_size = 1 # variable currently not used
config.epochs = 200
config.log_every_epochs = 5
config.eval_every_epochs = 5
config.checkpoint_every_epochs = 5

# GNN hyperparameters.
config.model = 'MLPBlock'
config.dropout_rate = 2e-5
config.skip_connections = False # This was throwing a broadcast error in add_graphs_tuples_nodes when this was set to True
config.layer_norm = False # TODO perhaps we want to turn on later
config.activation = "leaky_relu"

config.pred_x1 = True
config.pred_x2 = True

if config.pred_x1 and config.pred_x2:
    output_layer = 2
else:
    output_layer = 1

# choose the hidden layer feature size using powers of 2 
config.edge_features = (
    2**2,
    2**2,
)
config.node_features = (
    2**8,
    2**3,
    output_layer,
)
# note the last feature size will be the number of features that the graph predicts
config.global_features = None

# %%
# generate dataset 
x1_x2_same = create_dataset(config)
print_graph_fts(x1_x2_same['train']['inputs'][0][0])
# Out:
# Number of nodes: 36
# Number of edges: 180
# Node features shape: (36, 2)
# Edge features shape: (180, 1)
# Global features shape: (1, 1)

# %%
logger.setLevel(logging.INFO)

# %%
# generate a workdir 
# workdir="experiments/outputs/X1_X2_similar_dynamics_2"
workdir = tempfile.mkdtemp()

# run training 
state, train_metrics, eval_metrics_dict = train_and_evaluate_with_data(config=config, workdir=workdir, datasets=x1_x2_same)
# Out:
# INFO:absl:Hyperparameters: {'F': 8, 'K': 36, 'activation': 'leaky_relu', 'b': 1, 'batch_size': 1, 'c': 1, 'checkpoint_every_epochs': 5, 'dropout_rate': 2e-05, 'edge_features': (4, 4), 'epochs': 200, 'eval_every_epochs': 5, 'fully_connected_edges': False, 'global_features': None, 'h': 1, 'init_buffer_samples': 100, 'input_steps': 1, 'layer_norm': False, 'learning_rate': 0.0004, 'log_every_epochs': 5, 'max_checkpts_to_keep': None, 'model': 'MLPBlock', 'n_samples': 10000, 'node_features': (256, 8, 2), 'normalize': True, 'optimizer': 'adam', 'output_delay': 8, 'output_steps': 4, 'pred_x1': True, 'pred_x2': True, 'sample_buffer': -12, 'seed': 42, 'skip_connections': False, 'test_pct': 0.1, 'time_resolution': 120, 'timestep_duration': 3, 'train_pct': 0.7, 'val_pct': 0.2}
# INFO:absl:Initializing network.
# INFO:absl:
# +-----------------------------+-----------+-------+----------+-------+
# | Name                        | Shape     | Size  | Mean     | Std   |
# +-----------------------------+-----------+-------+----------+-------+
# | params/MLP_0/Dense_0/bias   | (4,)      | 4     | 0.0      | 0.0   |
# | params/MLP_0/Dense_0/kernel | (6, 4)    | 24    | -0.058   | 0.351 |
# | params/MLP_0/Dense_1/bias   | (4,)      | 4     | 0.0      | 0.0   |
# | params/MLP_0/Dense_1/kernel | (4, 4)    | 16    | 0.0556   | 0.457 |
# | params/MLP_1/Dense_0/bias   | (256,)    | 256   | 0.0      | 0.0   |
# | params/MLP_1/Dense_0/kernel | (11, 256) | 2,816 | -0.00268 | 0.313 |
# | params/MLP_1/Dense_1/bias   | (8,)      | 8     | 0.0      | 0.0   |
# | params/MLP_1/Dense_1/kernel | (256, 8)  | 2,048 | 0.00112  | 0.063 |
# | params/MLP_1/Dense_2/bias   | (2,)      | 2     | 0.0      | 0.0   |
# | params/MLP_1/Dense_2/kernel | (8, 2)    | 16    | -0.277   | 0.26  |
# +-----------------------------+-----------+-------+----------+-------+
# Total: 5,194
# INFO:absl:Checkpoint.restore_or_initialize() ...
# INFO:absl:No checkpoint specified. Restore the latest checkpoint.
# INFO:absl:Checkpoint None does not exist.
# INFO:absl:Checkpoint.save() ...
# INFO:absl:Checkpoint.save() finished after 0.00s.
# INFO:absl:Checkpoint.restore_or_initialize() finished after 0.00s.
# INFO:absl:Starting training.
# INFO:absl:Created artifact [10] Profile of type ArtifactType.URL and value None.
# INFO:absl:[0] train_loss=0.2993955910205841
# INFO:absl:[0] val_loss=0.23633337020874023
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[0] test_loss=0.26572611927986145
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[5] train_loss=0.15980809926986694
# INFO:absl:[5] val_loss=0.13818778097629547
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[5] test_loss=0.15941229462623596
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[10] train_loss=0.11223464459180832
# INFO:absl:[10] val_loss=0.1281394213438034
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[10] test_loss=0.14406423270702362
# INFO:absl:Checkpoint.save() finished after 0.00s.
# INFO:absl:[15] train_loss=0.10069434344768524
# INFO:absl:[15] val_loss=0.1132916510105133
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[15] test_loss=0.12723566591739655
# INFO:absl:Checkpoint.save() finished after 0.00s.
# INFO:absl:Setting work unit notes: 2055.4 steps/s, 8.8% (123327/1400000), ETA: 10m (1m : 0.0% checkpoint, 2.3% eval)
# INFO:absl:[123327] steps_per_sec=2055.440509
# INFO:absl:[20] train_loss=0.09209103882312775
# INFO:absl:[20] val_loss=0.1103479191660881
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[20] test_loss=0.12383273988962173
# INFO:absl:Checkpoint.save() finished after 0.00s.
# INFO:absl:[25] train_loss=0.08870390802621841
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[25] val_loss=0.10844976454973221
# INFO:absl:[25] test_loss=0.12172184139490128
# INFO:absl:Checkpoint.save() finished after 0.00s.
# INFO:absl:[30] train_loss=0.08647933602333069
# INFO:absl:[30] val_loss=0.10761933028697968
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[30] test_loss=0.12197679281234741
# INFO:absl:Checkpoint.save() finished after 0.00s.
# INFO:absl:[35] train_loss=0.0847327709197998
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[35] val_loss=0.1064504012465477
# INFO:absl:[35] test_loss=0.12196752429008484
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:Setting work unit notes: 2229.5 steps/s, 18.4% (257100/1400000), ETA: 8m (2m : 0.0% checkpoint, 2.1% eval)
# INFO:absl:[257100] steps_per_sec=2229.545685
# INFO:absl:[40] train_loss=0.08396179974079132
# INFO:absl:[40] val_loss=0.10360371321439743
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[40] test_loss=0.1189480796456337
# INFO:absl:Checkpoint.save() finished after 0.00s.
# INFO:absl:[45] train_loss=0.08270465582609177
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[45] val_loss=0.10486336052417755
# INFO:absl:[45] test_loss=0.12154702842235565
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[50] train_loss=0.08173835277557373
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[50] val_loss=0.10385072231292725
# INFO:absl:[50] test_loss=0.12063474953174591
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[55] train_loss=0.09561017155647278
# INFO:absl:[55] val_loss=0.10351113229990005
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[55] test_loss=0.11751902103424072
# INFO:absl:Checkpoint.save() finished after 0.00s.
# INFO:absl:Setting work unit notes: 
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[165] test_loss=0.11532318592071533
# INFO:absl:Checkpoint.save() finished after 0.00s.
# INFO:absl:Setting work unit notes: 2240.6 steps/s, 85.0% (1190447/1400000), ETA: 1m (9m : 0.0% checkpoint, 1.9% eval)
# INFO:absl:[1190447] steps_per_sec=2240.584775
# INFO:absl:[170] train_loss=0.07555679231882095
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[170] val_loss=0.09873778373003006
# INFO:absl:[170] test_loss=0.11383723467588425
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[175] train_loss=0.19084937870502472
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[175] val_loss=0.09944681078195572
# INFO:absl:[175] test_loss=0.11395557969808578
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[180] train_loss=0.07511215656995773
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[180] val_loss=0.1006448045372963
# INFO:absl:[180] test_loss=0.11654271185398102
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[185] train_loss=0.07510511577129364
# INFO:absl:[185] val_loss=0.09976238757371902
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[185] test_loss=0.11425276845693588
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:Setting work unit notes: 2230.4 steps/s, 94.6% (1324274/1400000), ETA: 0m (10m : 0.0% checkpoint, 1.9% eval)
# INFO:absl:[1324274] steps_per_sec=2230.444080
# INFO:absl:[190] train_loss=0.074945367872715
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[190] val_loss=0.09896083176136017
# INFO:absl:[190] test_loss=0.1136041209101677
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[195] train_loss=0.07474740594625473
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[195] val_loss=0.09674926847219467
# INFO:absl:[195] test_loss=0.1116742491722107
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[199] train_loss=0.07461315393447876
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[199] val_loss=0.09713150560855865
# INFO:absl:[199] test_loss=0.11131543666124344
# INFO:absl:Checkpoint.save() finished after 0.01s.

# %%
plot_predictions(
    config=config,
    workdir=workdir,
    plot_ith_rollout_step=0, # 0 indexed # for this study, we have a 4-step rollout 
    # dataset,
    # preds,
    # timestep_duration,
    # n_rollout_steps,
    #  total_steps,
    node=0, # 0-indexed 
    plot_mode="val", # i.e. "train"/"val"/"test"
    datasets=x1_x2_same,
    plot_days=60, 
)
# Out:
# INFO:root:Initializing network.
# Checkpoint directory: /var/folders/ms/_sf7k0cx6tn2h19y34_j6pd40000gn/T/tmplor5g4_1/checkpoints
# INFO:absl:
# +-----------------------------+-----------+-------+----------+-------+
# | Name                        | Shape     | Size  | Mean     | Std   |
# +-----------------------------+-----------+-------+----------+-------+
# | params/MLP_0/Dense_0/bias   | (4,)      | 4     | 0.0      | 0.0   |
# | params/MLP_0/Dense_0/kernel | (6, 4)    | 24    | -0.058   | 0.351 |
# | params/MLP_0/Dense_1/bias   | (4,)      | 4     | 0.0      | 0.0   |
# | params/MLP_0/Dense_1/kernel | (4, 4)    | 16    | 0.0556   | 0.457 |
# | params/MLP_1/Dense_0/bias   | (256,)    | 256   | 0.0      | 0.0   |
# | params/MLP_1/Dense_0/kernel | (11, 256) | 2,816 | -0.00268 | 0.313 |
# | params/MLP_1/Dense_1/bias   | (8,)      | 8     | 0.0      | 0.0   |
# | params/MLP_1/Dense_1/kernel | (256, 8)  | 2,048 | 0.00112  | 0.063 |
# | params/MLP_1/Dense_2/bias   | (2,)      | 2     | 0.0      | 0.0   |
# | params/MLP_1/Dense_2/kernel | (8, 2)    | 16    | -0.277   | 0.26  |
# +-----------------------------+-----------+-------+----------+-------+
# Total: 5,194
# INFO:absl:Checkpoint.restore_or_initialize() ...
# INFO:absl:Restoring checkpoint: /var/folders/ms/_sf7k0cx6tn2h19y34_j6pd40000gn/T/tmplor5g4_1/checkpoints/ckpt-42
# INFO:absl:Restored save_counter=42 restored_checkpoint=/var/folders/ms/_sf7k0cx6tn2h19y34_j6pd40000gn/T/tmplor5g4_1/checkpoints/ckpt-42
# INFO:absl:Checkpoint.restore_or_initialize() finished after 0.00s.
