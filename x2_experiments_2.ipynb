# %%
# %load_ext autoreload 
# %autoreload 2

from utils.jraph_data import get_lorenz_graph_tuples, print_graph_fts
from utils.lorenz import load_lorenz96_2coupled

import numpy as np
import jax.numpy as jnp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils.jraph_training import train_and_evaluate_with_data, create_dataset, evaluate_model, rollout, train_and_evaluate
# from utils.jraph_models import MLPGraphNetwork
from utils.jraph_data import print_graph_fts
from utils.jraph_vis import plot_predictions
from utils.hyperparam_tuning import remove_bad_trials, get_best_trial_config, get_best_trial_workdir
import ml_collections
import optuna 
from flax import linen as nn
from functools import partial
from datetime import datetime
import os 
import tempfile
import matplotlib.pyplot as plt 
import numpy as np 

import jax
from utils.jraph_training import create_dataset, create_model, create_optimizer
from clu import checkpoint
from clu import parameter_overview
from flax.training import train_state
from utils.lorenz import run_download_lorenz96_2coupled, load_lorenz96_2coupled
from utils.jraph_data import get_lorenz_graph_tuples, print_graph_fts
from utils.lorenz import load_lorenz96_2coupled

# %%
# set up logging
import logging
logger = logging.getLogger()
logger.setLevel(logging.WARNING)

# %%
from utils.jraph_training import train_and_evaluate_with_data, create_dataset
# from utils.jraph_models import MLPGraphNetwork
from utils.jraph_data import print_graph_fts
from utils.jraph_vis import plot_predictions
from utils.hyperparam_tuning import remove_bad_trials, get_best_trial_config, get_best_trial_workdir
import ml_collections
import optuna 
from flax import linen as nn
from functools import partial
from datetime import datetime
import os 
import tempfile

# %%
def get_data_config():
    config = ml_collections.ConfigDict()

    config.n_samples=10_000
    config.input_steps=1
    config.output_delay=8 # predict 24 hrs into the future 
    config.output_steps=4
    config.timestep_duration=3 # equivalent to 3 hours
    # note a 3 hour timestep resolution would be 5*24/3=40
    # if the time_resolution is 120, then a sampling frequency of 3 would achieve a 3 hour timestep 
    config.sample_buffer = -1 * (config.input_steps + config.output_delay + config.output_steps - 1) # negative buffer so that our sample input are continuous (i.e. the first sample would overlap a bit with consecutive samples) 
        # number of timesteps strictly between the end 
        # of one full sample and the start of the next sample
    config.time_resolution=120 # the number of 
                # raw data points generated per time unit, equivalent to the 
                # number of data points generated per 5 days in the simulation
    config.init_buffer_samples=100
    config.train_pct=0.7
    config.val_pct=0.2
    config.test_pct=0.1
    config.K=36
    config.F=8
    config.c=2
    config.b=1
    config.h=1
    config.seed=42
    config.normalize=True
    config.fully_connected_edges=False

    return config

# create config 
config = get_data_config()
config.max_checkpts_to_keep = None # None means keep all

# Optimizer.
config.optimizer = "adam"
config.learning_rate = 0.0004

# Data params that are used in training 
config.output_steps = 4

# Training hyperparameters.
config.batch_size = 1 # variable currently not used
config.epochs = 200
config.log_every_epochs = 5
config.eval_every_epochs = 5
config.checkpoint_every_epochs = 5

# GNN hyperparameters.
config.model = 'MLPBlock'
config.dropout_rate = 2e-5
config.skip_connections = False # This was throwing a broadcast error in add_graphs_tuples_nodes when this was set to True
config.layer_norm = False # TODO perhaps we want to turn on later
config.activation = "leaky_relu"

config.pred_x1 = True
config.pred_x2 = True

if config.pred_x1 and config.pred_x2:
    output_layer = 2
else:
    output_layer = 1

# choose the hidden layer feature size using powers of 2 
config.edge_features = (
    2**2,
    2**2,
)
config.node_features = (
    2**8,
    2**3,
    output_layer,
)
# note the last feature size will be the number of features that the graph predicts
config.global_features = None

# %%
# generate dataset 
x1_x2_same = create_dataset(config)
print_graph_fts(x1_x2_same['train']['inputs'][0][0])
# Out:
# Number of nodes: 36
# Number of edges: 180
# Node features shape: (36, 2)
# Edge features shape: (180, 1)
# Global features shape: (1, 1)

# %%
logger.setLevel(logging.INFO)

# %%
# generate a workdir 
# workdir="experiments/outputs/X1_X2_similar_dynamics_2"
workdir = tempfile.mkdtemp()

# run training 
state, train_metrics, eval_metrics_dict = train_and_evaluate_with_data(config=config, workdir=workdir, datasets=x1_x2_same)
# Out:
# INFO:absl:Hyperparameters: {'F': 8, 'K': 36, 'activation': 'leaky_relu', 'b': 1, 'batch_size': 1, 'c': 2, 'checkpoint_every_epochs': 5, 'dropout_rate': 2e-05, 'edge_features': (4, 4), 'epochs': 200, 'eval_every_epochs': 5, 'fully_connected_edges': False, 'global_features': None, 'h': 1, 'init_buffer_samples': 100, 'input_steps': 1, 'layer_norm': False, 'learning_rate': 0.0004, 'log_every_epochs': 5, 'max_checkpts_to_keep': None, 'model': 'MLPBlock', 'n_samples': 10000, 'node_features': (256, 8, 2), 'normalize': True, 'optimizer': 'adam', 'output_delay': 8, 'output_steps': 4, 'pred_x1': True, 'pred_x2': True, 'sample_buffer': -12, 'seed': 42, 'skip_connections': False, 'test_pct': 0.1, 'time_resolution': 120, 'timestep_duration': 3, 'train_pct': 0.7, 'val_pct': 0.2}
# INFO:absl:Initializing network.
# INFO:absl:
# +-----------------------------+-----------+-------+----------+-------+
# | Name                        | Shape     | Size  | Mean     | Std   |
# +-----------------------------+-----------+-------+----------+-------+
# | params/MLP_0/Dense_0/bias   | (4,)      | 4     | 0.0      | 0.0   |
# | params/MLP_0/Dense_0/kernel | (6, 4)    | 24    | -0.058   | 0.351 |
# | params/MLP_0/Dense_1/bias   | (4,)      | 4     | 0.0      | 0.0   |
# | params/MLP_0/Dense_1/kernel | (4, 4)    | 16    | 0.0556   | 0.457 |
# | params/MLP_1/Dense_0/bias   | (256,)    | 256   | 0.0      | 0.0   |
# | params/MLP_1/Dense_0/kernel | (11, 256) | 2,816 | -0.00268 | 0.313 |
# | params/MLP_1/Dense_1/bias   | (8,)      | 8     | 0.0      | 0.0   |
# | params/MLP_1/Dense_1/kernel | (256, 8)  | 2,048 | 0.00112  | 0.063 |
# | params/MLP_1/Dense_2/bias   | (2,)      | 2     | 0.0      | 0.0   |
# | params/MLP_1/Dense_2/kernel | (8, 2)    | 16    | -0.277   | 0.26  |
# +-----------------------------+-----------+-------+----------+-------+
# Total: 5,194
# INFO:absl:Checkpoint.restore_or_initialize() ...
# INFO:absl:No checkpoint specified. Restore the latest checkpoint.
# INFO:absl:Checkpoint None does not exist.
# INFO:absl:Checkpoint.save() ...
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:Checkpoint.restore_or_initialize() finished after 0.01s.
# INFO:absl:Starting training.
# INFO:absl:Finished training step 0.
# INFO:absl:Finished training step 1.
# INFO:absl:Finished training step 2.
# INFO:absl:Finished training step 3.
# INFO:absl:Finished training step 4.
# INFO:absl:Finished training step 5.
# INFO:absl:Finished training step 6.
# INFO:absl:Finished training step 7.
# INFO:absl:Finished training step 8.
# INFO:absl:Finished training step 9.
# INFO:absl:Created artifact [10] Profile of type ArtifactType.URL and value None.
# INFO:absl:[0] train_loss=0.3035407066345215
# INFO:absl:[0] val_loss=0.18948251008987427
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[0] test_loss=0.19344264268875122
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[5] train_loss=0.17529328167438507
# INFO:absl:[5] val_loss=0.13050642609596252
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[5] test_loss=0.12542463839054108
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[10] train_loss=0.14210744202136993
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[10] val_loss=0.11009521782398224
# INFO:absl:[10] test_loss=0.10587608814239502
# INFO:absl:Checkpoint.save() finished after 0.00s.
# INFO:absl:[15] train_loss=0.13085532188415527
# INFO:absl:[15] val_loss=0.10507224500179291
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[15] test_loss=0.10151513665914536
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:Setting work unit notes: 2110.7 steps/s, 9.0% (126644/1400000), ETA: 10m (1m : 0.0% checkpoint, 2.1% eval)
# INFO:absl:[126644] steps_per_sec=2110.729643
# INFO:absl:[20] train_loss=0.12493595480918884
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[20] val_loss=0.09879420697689056
# INFO:absl:[20] test_loss=0.09494002163410187
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[25] train_loss=0.12045655399560928
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[25] val_loss=0.0965292900800705
# INFO:absl:[25] test_loss=0.0922454297542572
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[30] train_loss=0.11723297834396362
# INFO:absl:[30] val_loss=0.09779781848192215
# INFO:absl:Checkpoint.save() ...
# INFO:absl:
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[130] test_loss=0.6647233963012695
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:Setting work unit notes: 2255.0 steps/s, 66.5% (931158/1400000), ETA: 3m (7m : 0.0% checkpoint, 1.9% eval)
# INFO:absl:[931158] steps_per_sec=2254.954310
# INFO:absl:[135] train_loss=58.41477966308594
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[135] val_loss=0.08887322247028351
# INFO:absl:[135] test_loss=0.0859866514801979
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[140] train_loss=0.10249826312065125
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[140] val_loss=0.08325637131929398
# INFO:absl:[140] test_loss=0.07945915311574936
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[145] train_loss=0.12574666738510132
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[145] val_loss=0.08612395823001862
# INFO:absl:[145] test_loss=0.08180304616689682
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[150] train_loss=0.20562055706977844
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[150] val_loss=0.13807475566864014
# INFO:absl:[150] test_loss=0.1375378966331482
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:Setting work unit notes: 2278.7 steps/s, 76.3% (1067881/1400000), ETA: 2m (8m : 0.0% checkpoint, 1.9% eval)
# INFO:absl:[1067881] steps_per_sec=2278.701129
# INFO:absl:[155] train_loss=0.10635660588741302
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[155] val_loss=0.08707120269536972
# INFO:absl:[155] test_loss=0.08273680508136749
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[160] train_loss=0.10033128410577774
# INFO:absl:[160] val_loss=0.08562176674604416
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[160] test_loss=0.0813300833106041
# INFO:absl:Checkpoint.save() finished after 0.00s.
# INFO:absl:[165] train_loss=2.2454850673675537
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[165] val_loss=0.08748916536569595
# INFO:absl:[165] test_loss=0.08294603228569031
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[170] train_loss=0.9731037020683289
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[170] val_loss=0.13744297623634338
# INFO:absl:[170] test_loss=0.13729552924633026
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:Setting work unit notes: 2298.3 steps/s, 86.1% (1205781/1400000), ETA: 1m (9m : 0.0% checkpoint, 1.9% eval)
# INFO:absl:[1205781] steps_per_sec=2298.323342
# INFO:absl:[175] train_loss=0.10446681082248688
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[175] val_loss=0.08521422743797302
# INFO:absl:[175] test_loss=0.08038264513015747
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[180] train_loss=1.7931545972824097
# INFO:absl:[180] val_loss=0.08046502619981766
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[180] test_loss=0.07634899020195007
# INFO:absl:Checkpoint.save() finished after 0.00s.
# INFO:absl:[185] train_loss=7709.31005859375
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[185] val_loss=0.13089965283870697
# INFO:absl:[185] test_loss=0.12747083604335785
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[190] train_loss=0.10428114235401154
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[190] val_loss=0.08307964354753494
# INFO:absl:[190] test_loss=0.07856065779924393
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:Setting work unit notes: 2231.8 steps/s, 95.7% (1339692/1400000), ETA: 0m (10m : 0.0% checkpoint, 1.9% eval)
# INFO:absl:[1339692] steps_per_sec=2231.838196
# INFO:absl:[195] train_loss=4.227721214294434
# INFO:absl:[195] val_loss=0.08479033410549164
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[195] test_loss=0.08026215434074402
# INFO:absl:Checkpoint.save() finished after 0.01s.
# INFO:absl:[199] train_loss=23.283790588378906
# INFO:absl:Checkpoint.save() ...
# INFO:absl:[199] val_loss=0.2115580439567566
# INFO:absl:[199] test_loss=0.20504096150398254
# INFO:absl:Checkpoint.save() finished after 0.01s.

# %%
plot_predictions(
    config=config,
    workdir=workdir,
    plot_ith_rollout_step=0, # 0 indexed # for this study, we have a 4-step rollout 
    # dataset,
    # preds,
    # timestep_duration,
    # n_rollout_steps,
    #  total_steps,
    node=0, # 0-indexed 
    plot_mode="val", # i.e. "train"/"val"/"test"
    datasets=x1_x2_same,
    plot_days=60, 
)
# Out:
# INFO:root:Initializing network.
# Checkpoint directory: /var/folders/ms/_sf7k0cx6tn2h19y34_j6pd40000gn/T/tmpbocagm9j/checkpoints
# INFO:absl:
# +-----------------------------+-----------+-------+----------+-------+
# | Name                        | Shape     | Size  | Mean     | Std   |
# +-----------------------------+-----------+-------+----------+-------+
# | params/MLP_0/Dense_0/bias   | (4,)      | 4     | 0.0      | 0.0   |
# | params/MLP_0/Dense_0/kernel | (6, 4)    | 24    | -0.058   | 0.351 |
# | params/MLP_0/Dense_1/bias   | (4,)      | 4     | 0.0      | 0.0   |
# | params/MLP_0/Dense_1/kernel | (4, 4)    | 16    | 0.0556   | 0.457 |
# | params/MLP_1/Dense_0/bias   | (256,)    | 256   | 0.0      | 0.0   |
# | params/MLP_1/Dense_0/kernel | (11, 256) | 2,816 | -0.00268 | 0.313 |
# | params/MLP_1/Dense_1/bias   | (8,)      | 8     | 0.0      | 0.0   |
# | params/MLP_1/Dense_1/kernel | (256, 8)  | 2,048 | 0.00112  | 0.063 |
# | params/MLP_1/Dense_2/bias   | (2,)      | 2     | 0.0      | 0.0   |
# | params/MLP_1/Dense_2/kernel | (8, 2)    | 16    | -0.277   | 0.26  |
# +-----------------------------+-----------+-------+----------+-------+
# Total: 5,194
# INFO:absl:Checkpoint.restore_or_initialize() ...
# INFO:absl:Restoring checkpoint: /var/folders/ms/_sf7k0cx6tn2h19y34_j6pd40000gn/T/tmpbocagm9j/checkpoints/ckpt-42
# INFO:absl:Restored save_counter=42 restored_checkpoint=/var/folders/ms/_sf7k0cx6tn2h19y34_j6pd40000gn/T/tmpbocagm9j/checkpoints/ckpt-42
# INFO:absl:Checkpoint.restore_or_initialize() finished after 0.00s.
